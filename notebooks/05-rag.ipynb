# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model


llm = init_chat_model("gpt-4.1-mini",temperature=0)

# %%
file_search_tool = {"type": "file_search", "vector_store_ids": ["vs_695bbe4a79248191806e48502f2c7bb0"]}
llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response=llm_with_tools.invoke("hola como estas?")
response.text
# Out:
# '¡Hola! Estoy bien, gracias. ¿Y tú, cómo estás? ¿En qué puedo ayudarte hoy?'

# %%
response=llm.invoke("informacion de mi factura")
response.text
# Out:
# '¡Hola! Para poder ayudarte con la información de tu factura, necesitaría un poco más de detalles. Por ejemplo:\n\n- ¿De qué tipo de factura estás hablando? (luz, agua, teléfono, internet, compra, etc.)\n- ¿De qué empresa o proveedor es la factura?\n- ¿Qué información específica necesitas? (monto, fecha de vencimiento, desglose, etc.)\n\nSi prefieres, también puedes revisar tu factura directamente en la página web o app del proveedor, o indicarme qué datos tienes y con gusto te ayudo a interpretarlos. ¡Quedo atento!'
