# %%
from langchain_core.messages import AIMessage
# from langchain_core.messages import AIMessage, HumanMessage, SystemMessage,ToolMessage

ai_msg=AIMessage(content="message from AI")
ai_msg.text
# Out:
# AIMessage(content='message from AI', additional_kwargs={}, response_metadata={})

# %%
from langchain_core.messages import HumanMessage

hm_msg=HumanMessage(content="message from Human")
hm_msg.text
# Out:
# HumanMessage(content='message from Human', additional_kwargs={}, response_metadata={})

# %%
history=[hm_msg,ai_msg]

for m in history:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# message from Human
# ================================== Ai Message ==================================
#
# message from AI

# %%
[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
history=history+[AIMessage(content="Another 2AI message")]

# %%
history[-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Another 2AI message
