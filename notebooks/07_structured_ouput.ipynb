# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model


llm = init_chat_model("gpt-41-mini",temperature=0)
response = llm.invoke("hola soy jose mi telefono es 1234567890")
response.text
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[2], line 5
#       1 from langchain.chat_models import init_chat_model
#       4 llm = init_chat_model("gpt-4o-mini",temperature=0)
# ----> 5 response = llm.invoke("hola soy jose mi telefono es 1234567890")
#       6 response.text
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1380, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1378     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1379         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1380     raise e
#    1381 if (
#    1382     self.include_response_headers
#    1383     and raw_response is not None
#    1384     and hasattr(raw_response, "headers")
#    1385 ):
#    1386     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1375, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1368         return _construct_lc_result_from_responses_api(
#    1369             response,
#    1370             schema=original_schema_obj,
#    1371             metadata=generation_info,
#    1372             output_version=self.output_version,
#    1373         )
#    1374     else:
# -> 1375         raw_response = self.client.with_raw_response.create(**payload)
#    1376         response = raw_response.parse()
#    1377 except Exception as e:
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\User\Documents\Platzi\Curso_para_Crear_Agentes_de_AI_con_LangGraph\my_course_agent\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'Project `proj_93nwgKspGHQTpHY5JHTiLek3` does not have access to model `gpt-4o-mini`', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
from pydantic import BaseModel,Field


class ContactInfo(BaseModel):
    """contact information schema"""
    name: str = Field(..., description="full name of the person")
    phone_number: str = Field(..., description="phone number of the person")
    email: str = Field(..., description="email address of the person")
    age: int = Field(..., description="age of the person", ge=0)
    tone: int = Field(..., description="the tone of the message, can be formal or informal", ge=1, le=10)
    sentiment: str = Field(..., description="the sentiment of the message, can be positive, negative or neutral")



llm_With_structured_output = llm.with_structured_output(schema=ContactInfo)


messages = [("system", "Eres un asistente que extrae informacion de los mensajes de los usuarios. no inventes informacion."),
            ("user", "hola soy jose mi telefono es 1234567890")]

response=llm_With_structured_output.invoke(messages)
response.model_dump()  # devuelve un diccionario con la informacion estructurada
# Out:
# {'name': 'Jose',
#  'phone_number': '1234567890',
#  'email': '',
#  'age': 0,
#  'tone': 1,
#  'sentiment': 'neutral'}

# %%
llm_With_structured_output
# Out:
# RunnableBinding(bound=ChatOpenAI(profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000024DDCAEBBC0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000024DDD011850>, root_client=<openai.OpenAI object at 0x0000024DDA427710>, root_async_client=<openai.AsyncOpenAI object at 0x0000024DDCB1F320>, model_name='gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********')), kwargs={'response_format': <class '__main__.ContactInfo'>, 'ls_structured_output_format': {'kwargs': {'method': 'json_schema', 'strict': None}, 'schema': {'type': 'function', 'function': {'name': 'ContactInfo', 'description': 'contact information schema', 'parameters': {'properties': {'name': {'description': 'full name of the person', 'type': 'string'}, 'phone_number': {'description': 'phone number of the person', 'type': 'string'}, 'email': {'description': 'email address of the person', 'type': 'string'}}, 'required': ['name', 'phone_number', 'email'], 'type': 'object'}}}}}, config={}, config_factories=[])
# | RunnableBinding(bound=RunnableLambda(...), kwargs={}, config={}, config_factories=[], custom_output_type=<class '__main__.ContactInfo'>)

# %%
response
# Out:
# AIMessage(content='¡Hola, José! ¿En qué puedo ayudarte hoy?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 18, 'total_tokens': 30, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cw6wVJJBeJl2lfnF483i4sNDY5zMz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba2f8-6a23-72c3-b45c-9e3636d7a6e2-0', usage_metadata={'input_tokens': 18, 'output_tokens': 12, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
